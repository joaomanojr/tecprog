# %% [markdown]
# <a href="https://colab.research.google.com/github/joaomanojr/tecprog/blob/main/frozen_lake.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from platform import python_version

print(python_version())
# Out:
# 3.7.10

# %%
import numpy as np

import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch as T

class LinearDeepQNetwork(nn.Module):
    def __init__(self, lr, n_actions, input):
        super(LinearDeepQNetwork, self).__init__()

        self.fc1 = nn.Linear(input, 128)
        self.fc2 = nn.Linear(128, n_actions)

        # Author: self.parameters() from inherited class Module
        self.optimizer = optim.Adam(self.parameters(), lr=lr)
        self.loss = nn.MSELoss()
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        # Author: pytorch have different tensors for cuda/cpu devices
        self.to(self.device)

    def forward(self, state):
        layer1 = F.relu(self.fc1(state))
        # Author: MSELoss will take care of activation for us...
        actions = self.fc2(layer1)

        return actions


class Agent():
    def __init__(self, lr, n_actions, gamma=0.95,
                 epsilon=1.0, eps_dec=1e-5, eps_min=0.01):
        """ Agent init takes:
        --
        lr - alpha learning rate factor
        input_dims - from our environment dimensions
        n_actions - actions space dimension
        gamma - discount factor on MDP rewards
        epsilon - Epsilon Greedy initial value (exploration threshold)
        eps_dec - Epsilon Greedy decrease factor
        eps_min - Epsilon Greedy minimum, final value (must be > 0)
        
        """
        self.lr = lr
        # Joao: hardcoded as 1
        self.input_dims = 1
        self.n_actions = n_actions
        self.gamma = gamma
        self.epsilon = epsilon
        self.eps_dec = eps_dec
        self.eps_min = eps_min
        self.action_space = [i for i in range(self.n_actions)]

        self.Q = LinearDeepQNetwork(self.lr, self.n_actions, self.input_dims)

    def choose_action(self, observation):
        ''' Choose Epsilon Greedy action for a given state '''
        if np.random.random() > self.epsilon:
            state = T.tensor(observation, dtype=T.float).to(self.Q.device)
            # https://stackoverflow.com/questions/64192810/runtime-error-both-arguments-to-matmul-need-to-be-at-least-1d-but-they-are-0d
            actions = self.Q.forward(state.unsqueeze(dim=0))
            action = T.argmax(actions).item()
        else:
            action = np.random.choice(self.action_space)

        return action
    
    def decrement_epsilon(self):
        ''' Epsilon decrease function (linear) '''
        # Look: my beloved C ternary in python terms!
        self.epsilon = self.epsilon - self.eps_dec \
                        if self.epsilon > self.eps_min else self.eps_min
    
    def learn(self, state, action, reward, state_):
        """ Off Policy (always Greedy) Learn function 
        --
        Here defined as plain Bellman equation, state_ is state'
        """
        self.Q.optimizer.zero_grad()

        states = T.tensor(state, dtype=T.float).to(self.Q.device)
        actions = T.tensor(action).to(self.Q.device)
        rewards = T.tensor(reward).to(self.Q.device)
        states_ = T.tensor(state_, dtype=T.float).to(self.Q.device)

        print("states")
        print(self.Q.forward(states.unsqueeze(dim=0)))

        q_pred = self.Q.forward(states.unsqueeze(dim=0))[actions]
        print(f"q_pred= {self.Q.forward(states.unsqueeze(dim=0))}")
        #print(self.Q.forward(actions.unsqueeze(dim=0))[actions])
        q_next = self.Q.forward(states_.unsqueeze(dim=0)).max()

        q_target = reward + self.gamma*q_next

        # evaluate loss (cost) as the difference at better known and actual
        # action.
        loss = self.Q.loss(q_pred, q_target).to(self.Q.device)
        # Author: backpropagate cost and add a step on our optimizer.
        # These two calls are critical for learn loop.
        loss.backward()

        self.Q.optimizer.step()
        self.decrement_epsilon()

# %%
import gym
import matplotlib.pyplot as plt
import numpy as np
#from deepq_learning_agent import Agent

env = gym.make('FrozenLake-v0')

obs = env.reset()
print(obs)
# Out:
# 0

# %%
env = gym.make('FrozenLake-v0')

# %%
n_games = 100
scores = []
win_pct_list = []

agent = Agent(lr=0.0001, n_actions=4)

for i in range(n_games):
    score = 0
    done = False
    # This looks like a context pointer to created environment, here we are
    # just initializing it - it returns our current state also;
    obs = env.reset()

    # Interact with environment until done (end or fall in a hole)
    while not done:
        action = agent.choose_action(obs)
        obs_, reward, done, info = env.step(action)
        #env.render()
        score += reward
        agent.learn(obs, action, reward, obs_)
        obs = obs_
    scores.append(score)

    if i % 100 == 0:
        win_pct = np.mean(scores[-100:])
        win_pct_list.append(win_pct)
        print('episode', i, 'win pct %.2f' % win_pct,
                  'epsilon %.2f' % agent.epsilon)

plt.plot(win_pct_list)
plt.show()
# Out:
# states
# tensor([-0.2609,  0.4139,  0.3323, -0.0574], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2609,  0.4139,  0.3323, -0.0574], grad_fn=<AddBackward0>)
# states
# tensor([-0.5141,  0.5324,  0.6490, -0.0460], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.5141,  0.5324,  0.6490, -0.0460], grad_fn=<AddBackward0>)
# states
# tensor([-0.2590,  0.4153,  0.3281, -0.0574], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2590,  0.4153,  0.3281, -0.0574], grad_fn=<AddBackward0>)
# states
# tensor([-0.5083,  0.5287,  0.6429, -0.0437], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.5083,  0.5287,  0.6429, -0.0437], grad_fn=<AddBackward0>)
# episode 0 win pct 0.00 epsilon 1.00
# states
# tensor([-0.2558,  0.4128,  0.3246, -0.0537], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2558,  0.4128,  0.3246, -0.0537], grad_fn=<AddBackward0>)
# states
# tensor([-1.0277,  1.6110,  2.0756,  0.4351], grad_fn=<AddBackward0>)
# q_pred= tensor([-1.0277,  1.6110,  2.0756,  0.4351], grad_fn=<AddBackward0>)
# states
# tensor([-0.2515,  0.4128,  0.3209, -0.0512], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2515,  0.4128,  0.3209, -0.0512], grad_fn=<AddBackward0>)
# states
# tensor([-0.2498,  0.4137,  0.3197, -0.0501], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2498,  0.4137,  0.3197, -0.0501], grad_fn=<AddBackward0>)
# states
# tensor([-0.2480,  0.4139,  0.3186, -0.0492], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2480,  0.4139,  0.3186, -0.0492], grad_fn=<AddBackward0>)
# states
# tensor([-0.2465,  0.4137,  0.3177, -0.0477], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2465,  0.4137,  0.3177, -0.0477], grad_fn=<AddBackward0>)
# states
# tensor([-0.4914,  0.5284,  0.6237, -0.0336], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4914,  0.5284,  0.6237, -0.0336], grad_fn=<AddBackward0>)
# states
# tensor([-0.4898,  0.5284,  0.6215, -0.0313], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4898,  0.5284,  0.6215, -0.0313], grad_fn=<AddBackward0>)
# states
# tensor([-0.2424,  0.4131,  0.3146, -0.0432], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2424,  0.4131,  0.3146, -0.0432], grad_fn=<AddBackward0>)
# states
# tensor([-0.9896,  1.6139,  2.0193,  0.4647], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.9896,  1.6139,  2.0193,  0.4647], grad_fn=<AddBackward0>)
# states
# tensor([-0.2401,  0.4139,  0.3124, -0.0406], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2401,  0.4139,  0.3124, -0.0406], grad_fn=<AddBackward0>)
# states
# tensor([-0.9817,  1.6153,  2.0063,  0.4728], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.9817,  1.6153,  2.0063,  0.4728], grad_fn=<AddBackward0>)
# states
# tensor([-1.7208,  3.1619,  3.8308,  1.0327], grad_fn=<AddBackward0>)
# q_pred= tensor([-1.7208,  3.1619,  3.8308,  1.0327], grad_fn=<AddBackward0>)
# states
# tensor([-0.9713,  1.6164,  1.9891,  0.4794], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.9713,  1.6164,  1.9891,  0.4794], grad_fn=<AddBackward0>)
# states
# tensor([-0.9653,  1.6209,  1.9805,  0.4822], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.9653,  1.6209,  1.9805,  0.4822], grad_fn=<AddBackward0>)
# states
# tensor([-1.6857,  3.1841,  3.7766,  1.0481], grad_fn=<AddBackward0>)
# q_pred= tensor([-1.6857,  3.1841,  3.7766,  1.0481], grad_fn=<AddBackward0>)
# states
# tensor([-1.8775,  3.5899,  4.2063,  1.1871], grad_fn=<AddBackward0>)
# q_pred= tensor([-1.8775,  3.5899,  4.2063,  1.1871], grad_fn=<AddBackward0>)
# states
# tensor([-0.2297,  0.4183,  0.3028, -0.0346], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2297,  0.4183,  0.3028, -0.0346], grad_fn=<AddBackward0>)
# states
# tensor([-0.2283,  0.4192,  0.3017, -0.0341], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2283,  0.4192,  0.3017, -0.0341], grad_fn=<AddBackward0>)
# states
# tensor([-0.2269,  0.4197,  0.3006, -0.0335], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2269,  0.4197,  0.3006, -0.0335], grad_fn=<AddBackward0>)
# states
# tensor([-0.2254,  0.4199,  0.2997, -0.0331], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2254,  0.4199,  0.2997, -0.0331], grad_fn=<AddBackward0>)
# states
# tensor([-0.4618,  0.5435,  0.5834, -0.0143], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4618,  0.5435,  0.5834, -0.0143], grad_fn=<AddBackward0>)
# states
# tensor([-0.2229,  0.4201,  0.2976, -0.0304], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2229,  0.4201,  0.2976, -0.0304], grad_fn=<AddBackward0>)
# states
# tensor([-0.4585,  0.5454,  0.5789, -0.0106], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4585,  0.5454,  0.5789, -0.0106], grad_fn=<AddBackward0>)
# states
# tensor([-0.2208,  0.4207,  0.2955, -0.0278], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2208,  0.4207,  0.2955, -0.0278], grad_fn=<AddBackward0>)
# states
# tensor([-0.2198,  0.4211,  0.2948, -0.0267], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2198,  0.4211,  0.2948, -0.0267], grad_fn=<AddBackward0>)
# states
# tensor([-0.2188,  0.4212,  0.2942, -0.0257], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2188,  0.4212,  0.2942, -0.0257], grad_fn=<AddBackward0>)
# states
# tensor([-0.2177,  0.4211,  0.2936, -0.0247], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2177,  0.4211,  0.2936, -0.0247], grad_fn=<AddBackward0>)
# states
# tensor([-0.8956,  1.6906,  1.8691,  0.5226], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.8956,  1.6906,  1.8691,  0.5226], grad_fn=<AddBackward0>)
# states
# tensor([-0.2156,  0.4203,  0.2937, -0.0231], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2156,  0.4203,  0.2937, -0.0231], grad_fn=<AddBackward0>)
# states
# tensor([-0.8887,  1.6947,  1.8575,  0.5274], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.8887,  1.6947,  1.8575,  0.5274], grad_fn=<AddBackward0>)
# states
# tensor([-0.2128,  0.4193,  0.2932, -0.0218], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2128,  0.4193,  0.2932, -0.0218], grad_fn=<AddBackward0>)
# states
# tensor([-4.4667e-01,  5.5160e-01,  5.6283e-01, -2.8193e-04],
#        grad_fn=<AddBackward0>)
# q_pred= tensor([-4.4667e-01,  5.5160e-01,  5.6283e-01, -2.8193e-04],
#        grad_fn=<AddBackward0>)
# states
# tensor([-0.6109,  0.9040,  0.9657,  0.2058], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.6109,  0.9040,  0.9657,  0.2058], grad_fn=<AddBackward0>)
# states
# tensor([-1.1835,  2.5153,  2.6718,  0.8478], grad_fn=<AddBackward0>)
# q_pred= tensor([-1.1835,  2.5153,  2.6718,  0.8478], grad_fn=<AddBackward0>)
# states
# tensor([-0.2085,  0.4178,  0.2928, -0.0197], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2085,  0.4178,  0.2928, -0.0197], grad_fn=<AddBackward0>)
# states
# tensor([-0.8739,  1.7011,  1.8262,  0.5372], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.8739,  1.7011,  1.8262,  0.5372], grad_fn=<AddBackward0>)
# states
# tensor([-0.8704,  1.7009,  1.8196,  0.5384], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.8704,  1.7009,  1.8196,  0.5384], grad_fn=<AddBackward0>)
# states
# tensor([-0.2057,  0.4168,  0.2932, -0.0177], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2057,  0.4168,  0.2932, -0.0177], grad_fn=<AddBackward0>)
# states
# tensor([-0.2048,  0.4165,  0.2931, -0.0167], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2048,  0.4165,  0.2931, -0.0167], grad_fn=<AddBackward0>)
# states
# tensor([-0.2040,  0.4161,  0.2930, -0.0157], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2040,  0.4161,  0.2930, -0.0157], grad_fn=<AddBackward0>)
# states
# tensor([-0.2033,  0.4159,  0.2929, -0.0148], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2033,  0.4159,  0.2929, -0.0148], grad_fn=<AddBackward0>)
# states
# tensor([-0.4363,  0.5512,  0.5478,  0.0124], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4363,  0.5512,  0.5478,  0.0124], grad_fn=<AddBackward0>)
# states
# tensor([-0.2021,  0.4159,  0.2926, -0.0132], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2021,  0.4159,  0.2926, -0.0132], grad_fn=<AddBackward0>)
# states
# tensor([-0.8535,  1.7021,  1.7766,  0.5788], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.8535,  1.7021,  1.7766,  0.5788], grad_fn=<AddBackward0>)
# states
# tensor([-0.2010,  0.4165,  0.2929, -0.0119], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2010,  0.4165,  0.2929, -0.0119], grad_fn=<AddBackward0>)
# states
# tensor([-0.2006,  0.4166,  0.2931, -0.0109], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2006,  0.4166,  0.2931, -0.0109], grad_fn=<AddBackward0>)
# states
# tensor([-0.8491,  1.7071,  1.7589,  0.5898], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.8491,  1.7071,  1.7589,  0.5898], grad_fn=<AddBackward0>)
# states
# tensor([-0.8479,  1.7084,  1.7527,  0.5970], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.8479,  1.7084,  1.7527,  0.5970], grad_fn=<AddBackward0>)
# states
# tensor([-0.1995,  0.4170,  0.2940, -0.0073], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1995,  0.4170,  0.2940, -0.0073], grad_fn=<AddBackward0>)
# states
# tensor([-0.1992,  0.4169,  0.2942, -0.0058], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1992,  0.4169,  0.2942, -0.0058], grad_fn=<AddBackward0>)
# states
# tensor([-0.4314,  0.5554,  0.5350,  0.0269], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4314,  0.5554,  0.5350,  0.0269], grad_fn=<AddBackward0>)
# states
# tensor([-0.1985,  0.4164,  0.2948, -0.0032], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1985,  0.4164,  0.2948, -0.0032], grad_fn=<AddBackward0>)
# states
# tensor([-0.8431,  1.7124,  1.7280,  0.6212], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.8431,  1.7124,  1.7280,  0.6212], grad_fn=<AddBackward0>)
# states
# tensor([-0.1978,  0.4166,  0.2950, -0.0010], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1978,  0.4166,  0.2950, -0.0010], grad_fn=<AddBackward0>)
# states
# tensor([-0.4298,  0.5554,  0.5308,  0.0328], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4298,  0.5554,  0.5308,  0.0328], grad_fn=<AddBackward0>)
# states
# tensor([-0.4294,  0.5552,  0.5299,  0.0342], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4294,  0.5552,  0.5299,  0.0342], grad_fn=<AddBackward0>)
# states
# tensor([-0.1966,  0.4156,  0.2953,  0.0031], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1966,  0.4156,  0.2953,  0.0031], grad_fn=<AddBackward0>)
# states
# tensor([-0.1960,  0.4146,  0.2954,  0.0046], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1960,  0.4146,  0.2954,  0.0046], grad_fn=<AddBackward0>)
# states
# tensor([-0.4273,  0.5492,  0.5277,  0.0384], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4273,  0.5492,  0.5277,  0.0384], grad_fn=<AddBackward0>)
# states
# tensor([-0.1950,  0.4128,  0.2955,  0.0082], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1950,  0.4128,  0.2955,  0.0082], grad_fn=<AddBackward0>)
# states
# tensor([-0.4262,  0.5449,  0.5266,  0.0411], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4262,  0.5449,  0.5266,  0.0411], grad_fn=<AddBackward0>)
# states
# tensor([-0.1941,  0.4113,  0.2957,  0.0112], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1941,  0.4113,  0.2957,  0.0112], grad_fn=<AddBackward0>)
# states
# tensor([-0.1937,  0.4106,  0.2959,  0.0125], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1937,  0.4106,  0.2959,  0.0125], grad_fn=<AddBackward0>)
# states
# tensor([-0.1934,  0.4098,  0.2961,  0.0140], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1934,  0.4098,  0.2961,  0.0140], grad_fn=<AddBackward0>)
# states
# tensor([-0.1931,  0.4089,  0.2962,  0.0158], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1931,  0.4089,  0.2962,  0.0158], grad_fn=<AddBackward0>)
# states
# tensor([-0.4242,  0.5366,  0.5240,  0.0469], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4242,  0.5366,  0.5240,  0.0469], grad_fn=<AddBackward0>)
# states
# tensor([-0.5814,  0.8743,  0.8881,  0.2770], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.5814,  0.8743,  0.8881,  0.2770], grad_fn=<AddBackward0>)
# states
# tensor([-1.1176,  2.4210,  2.4466,  1.0304], grad_fn=<AddBackward0>)
# q_pred= tensor([-1.1176,  2.4210,  2.4466,  1.0304], grad_fn=<AddBackward0>)
# states
# tensor([-1.7884,  3.9678,  3.9769,  1.7316], grad_fn=<AddBackward0>)
# q_pred= tensor([-1.7884,  3.9678,  3.9769,  1.7316], grad_fn=<AddBackward0>)
# states
# tensor([-1.6136,  3.5558,  3.5956,  1.5616], grad_fn=<AddBackward0>)
# q_pred= tensor([-1.6136,  3.5558,  3.5956,  1.5616], grad_fn=<AddBackward0>)
# states
# tensor([-1.7866,  3.9194,  3.9775,  1.7406], grad_fn=<AddBackward0>)
# q_pred= tensor([-1.7866,  3.9194,  3.9775,  1.7406], grad_fn=<AddBackward0>)
# states
# tensor([-0.1917,  0.4023,  0.2974,  0.0265], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1917,  0.4023,  0.2974,  0.0265], grad_fn=<AddBackward0>)
# states
# tensor([-0.1913,  0.4012,  0.2976,  0.0276], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1913,  0.4012,  0.2976,  0.0276], grad_fn=<AddBackward0>)
# states
# tensor([-0.1907,  0.3999,  0.2978,  0.0285], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1907,  0.3999,  0.2978,  0.0285], grad_fn=<AddBackward0>)
# states
# tensor([-0.1900,  0.3985,  0.2979,  0.0294], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1900,  0.3985,  0.2979,  0.0294], grad_fn=<AddBackward0>)
# states
# tensor([-0.4214,  0.5160,  0.5229,  0.0585], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4214,  0.5160,  0.5229,  0.0585], grad_fn=<AddBackward0>)
# states
# tensor([-0.1888,  0.3961,  0.2981,  0.0319], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1888,  0.3961,  0.2981,  0.0319], grad_fn=<AddBackward0>)
# states
# tensor([-0.1882,  0.3950,  0.2982,  0.0329], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1882,  0.3950,  0.2982,  0.0329], grad_fn=<AddBackward0>)
# states
# tensor([-0.1875,  0.3938,  0.2984,  0.0339], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1875,  0.3938,  0.2984,  0.0339], grad_fn=<AddBackward0>)
# states
# tensor([-0.4199,  0.5101,  0.5220,  0.0615], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4199,  0.5101,  0.5220,  0.0615], grad_fn=<AddBackward0>)
# states
# tensor([-0.1863,  0.3922,  0.2984,  0.0355], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1863,  0.3922,  0.2984,  0.0355], grad_fn=<AddBackward0>)
# states
# tensor([-0.1858,  0.3917,  0.2984,  0.0362], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1858,  0.3917,  0.2984,  0.0362], grad_fn=<AddBackward0>)
# states
# tensor([-0.1853,  0.3912,  0.2983,  0.0368], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1853,  0.3912,  0.2983,  0.0368], grad_fn=<AddBackward0>)
# states
# tensor([-0.1849,  0.3908,  0.2982,  0.0374], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1849,  0.3908,  0.2982,  0.0374], grad_fn=<AddBackward0>)
# states
# tensor([-0.4185,  0.5073,  0.5191,  0.0639], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4185,  0.5073,  0.5191,  0.0639], grad_fn=<AddBackward0>)
# states
# tensor([-0.1840,  0.3898,  0.2981,  0.0384], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1840,  0.3898,  0.2981,  0.0384], grad_fn=<AddBackward0>)
# states
# tensor([-0.4178,  0.5061,  0.5182,  0.0649], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4178,  0.5061,  0.5182,  0.0649], grad_fn=<AddBackward0>)
# states
# tensor([-0.1829,  0.3883,  0.2977,  0.0402], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1829,  0.3883,  0.2977,  0.0402], grad_fn=<AddBackward0>)
# states
# tensor([-0.1824,  0.3873,  0.2976,  0.0413], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1824,  0.3873,  0.2976,  0.0413], grad_fn=<AddBackward0>)
# states
# tensor([-0.1819,  0.3864,  0.2974,  0.0424], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1819,  0.3864,  0.2974,  0.0424], grad_fn=<AddBackward0>)
# states
# tensor([-0.1812,  0.3854,  0.2973,  0.0433], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1812,  0.3854,  0.2973,  0.0433], grad_fn=<AddBackward0>)
# states
# tensor([-0.1806,  0.3842,  0.2972,  0.0445], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1806,  0.3842,  0.2972,  0.0445], grad_fn=<AddBackward0>)
# states
# tensor([-0.4151,  0.5017,  0.5159,  0.0689], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4151,  0.5017,  0.5159,  0.0689], grad_fn=<AddBackward0>)
# states
# tensor([-0.5725,  0.8193,  0.8706,  0.2999], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.5725,  0.8193,  0.8706,  0.2999], grad_fn=<AddBackward0>)
# states
# tensor([-0.4144,  0.5006,  0.5153,  0.0700], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4144,  0.5006,  0.5153,  0.0700], grad_fn=<AddBackward0>)
# states
# tensor([-0.1787,  0.3808,  0.2972,  0.0482], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1787,  0.3808,  0.2972,  0.0482], grad_fn=<AddBackward0>)
# states
# tensor([-0.1781,  0.3799,  0.2973,  0.0490], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1781,  0.3799,  0.2973,  0.0490], grad_fn=<AddBackward0>)
# states
# tensor([-0.8185,  1.5348,  1.6441,  0.6934], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.8185,  1.5348,  1.6441,  0.6934], grad_fn=<AddBackward0>)
# states
# tensor([-0.1771,  0.3801,  0.2968,  0.0502], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1771,  0.3801,  0.2968,  0.0502], grad_fn=<AddBackward0>)
# states
# tensor([-0.1766,  0.3804,  0.2966,  0.0507], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1766,  0.3804,  0.2966,  0.0507], grad_fn=<AddBackward0>)
# states
# tensor([-0.1762,  0.3807,  0.2964,  0.0512], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1762,  0.3807,  0.2964,  0.0512], grad_fn=<AddBackward0>)
# states
# tensor([-0.1759,  0.3808,  0.2962,  0.0520], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1759,  0.3808,  0.2962,  0.0520], grad_fn=<AddBackward0>)
# states
# tensor([-0.1753,  0.3807,  0.2960,  0.0527], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1753,  0.3807,  0.2960,  0.0527], grad_fn=<AddBackward0>)
# states
# tensor([-0.1745,  0.3803,  0.2958,  0.0534], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1745,  0.3803,  0.2958,  0.0534], grad_fn=<AddBackward0>)
# states
# tensor([-0.8161,  1.5320,  1.6205,  0.6961], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.8161,  1.5320,  1.6205,  0.6961], grad_fn=<AddBackward0>)
# states
# tensor([-0.1719,  0.3797,  0.2949,  0.0545], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1719,  0.3797,  0.2949,  0.0545], grad_fn=<AddBackward0>)
# states
# tensor([-0.8147,  1.5325,  1.6107,  0.6966], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.8147,  1.5325,  1.6107,  0.6966], grad_fn=<AddBackward0>)
# states
# tensor([-1.4174,  2.9994,  3.0570,  1.4369], grad_fn=<AddBackward0>)
# q_pred= tensor([-1.4174,  2.9994,  3.0570,  1.4369], grad_fn=<AddBackward0>)
# states
# tensor([-1.5874,  3.3647,  3.3996,  1.6404], grad_fn=<AddBackward0>)
# q_pred= tensor([-1.5874,  3.3647,  3.3996,  1.6404], grad_fn=<AddBackward0>)
# states
# tensor([-1.4159,  2.9994,  3.0174,  1.4870], grad_fn=<AddBackward0>)
# q_pred= tensor([-1.4159,  2.9994,  3.0174,  1.4870], grad_fn=<AddBackward0>)
# states
# tensor([-1.5860,  3.3643,  3.3471,  1.7131], grad_fn=<AddBackward0>)
# q_pred= tensor([-1.5860,  3.3643,  3.3471,  1.7131], grad_fn=<AddBackward0>)
# states
# tensor([-1.7568,  3.7269,  3.6739,  1.9438], grad_fn=<AddBackward0>)
# q_pred= tensor([-1.7568,  3.7269,  3.6739,  1.9438], grad_fn=<AddBackward0>)
# states
# tensor([-1.5644,  3.3355,  3.2998,  1.7819], grad_fn=<AddBackward0>)
# q_pred= tensor([-1.5644,  3.3355,  3.2998,  1.7819], grad_fn=<AddBackward0>)
# states
# tensor([-1.3792,  2.9485,  2.9319,  1.6171], grad_fn=<AddBackward0>)
# q_pred= tensor([-1.3792,  2.9485,  2.9319,  1.6171], grad_fn=<AddBackward0>)
# states
# tensor([-0.7860,  1.4957,  1.5320,  0.8028], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.7860,  1.4957,  1.5320,  0.8028], grad_fn=<AddBackward0>)
# states
# tensor([-0.1569,  0.3728,  0.2842,  0.0720], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1569,  0.3728,  0.2842,  0.0720], grad_fn=<AddBackward0>)
# states
# tensor([-0.1554,  0.3714,  0.2832,  0.0739], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1554,  0.3714,  0.2832,  0.0739], grad_fn=<AddBackward0>)
# states
# tensor([-0.1540,  0.3702,  0.2823,  0.0757], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1540,  0.3702,  0.2823,  0.0757], grad_fn=<AddBackward0>)
# states
# tensor([-0.1528,  0.3689,  0.2815,  0.0776], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1528,  0.3689,  0.2815,  0.0776], grad_fn=<AddBackward0>)
# states
# tensor([-0.1514,  0.3675,  0.2807,  0.0793], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1514,  0.3675,  0.2807,  0.0793], grad_fn=<AddBackward0>)
# states
# tensor([-0.3858,  0.4724,  0.4685,  0.1295], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3858,  0.4724,  0.4685,  0.1295], grad_fn=<AddBackward0>)
# states
# tensor([-0.5308,  0.7668,  0.7821,  0.4037], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.5308,  0.7668,  0.7821,  0.4037], grad_fn=<AddBackward0>)
# states
# tensor([-0.5288,  0.7640,  0.7794,  0.4082], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.5288,  0.7640,  0.7794,  0.4082], grad_fn=<AddBackward0>)
# states
# tensor([-0.5271,  0.7614,  0.7769,  0.4123], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.5271,  0.7614,  0.7769,  0.4123], grad_fn=<AddBackward0>)
# states
# tensor([-0.5251,  0.7591,  0.7743,  0.4159], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.5251,  0.7591,  0.7743,  0.4159], grad_fn=<AddBackward0>)
# states
# tensor([-0.6337,  1.0774,  1.1182,  0.6660], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.6337,  1.0774,  1.1182,  0.6660], grad_fn=<AddBackward0>)
# states
# tensor([-0.5211,  0.7552,  0.7685,  0.4232], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.5211,  0.7552,  0.7685,  0.4232], grad_fn=<AddBackward0>)
# states
# tensor([-0.9700,  2.0899,  2.0933,  1.4165], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.9700,  2.0899,  2.0933,  1.4165], grad_fn=<AddBackward0>)
# states
# tensor([-0.1419,  0.3596,  0.2730,  0.0930], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1419,  0.3596,  0.2730,  0.0930], grad_fn=<AddBackward0>)
# states
# tensor([-0.1409,  0.3590,  0.2719,  0.0944], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1409,  0.3590,  0.2719,  0.0944], grad_fn=<AddBackward0>)
# states
# tensor([-0.7156,  1.4071,  1.4254,  0.9421], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.7156,  1.4071,  1.4254,  0.9421], grad_fn=<AddBackward0>)
# states
# tensor([-0.1390,  0.3585,  0.2707,  0.0968], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1390,  0.3585,  0.2707,  0.0968], grad_fn=<AddBackward0>)
# states
# tensor([-0.7098,  1.4034,  1.4099,  0.9502], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.7098,  1.4034,  1.4099,  0.9502], grad_fn=<AddBackward0>)
# states
# tensor([-0.1375,  0.3592,  0.2693,  0.0990], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1375,  0.3592,  0.2693,  0.0990], grad_fn=<AddBackward0>)
# states
# tensor([-0.1367,  0.3593,  0.2687,  0.1001], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1367,  0.3593,  0.2687,  0.1001], grad_fn=<AddBackward0>)
# states
# tensor([-0.7027,  1.3948,  1.3905,  0.9638], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.7027,  1.3948,  1.3905,  0.9638], grad_fn=<AddBackward0>)
# states
# tensor([-0.1340,  0.3583,  0.2676,  0.1019], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1340,  0.3583,  0.2676,  0.1019], grad_fn=<AddBackward0>)
# states
# tensor([-0.3632,  0.4546,  0.4353,  0.1629], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3632,  0.4546,  0.4353,  0.1629], grad_fn=<AddBackward0>)
# states
# tensor([-0.1316,  0.3567,  0.2670,  0.1041], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1316,  0.3567,  0.2670,  0.1041], grad_fn=<AddBackward0>)
# states
# tensor([-0.1306,  0.3558,  0.2670,  0.1053], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1306,  0.3558,  0.2670,  0.1053], grad_fn=<AddBackward0>)
# states
# tensor([-0.1297,  0.3549,  0.2669,  0.1064], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1297,  0.3549,  0.2669,  0.1064], grad_fn=<AddBackward0>)
# states
# tensor([-0.3592,  0.4489,  0.4319,  0.1676], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3592,  0.4489,  0.4319,  0.1676], grad_fn=<AddBackward0>)
# states
# tensor([-0.1281,  0.3536,  0.2668,  0.1083], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1281,  0.3536,  0.2668,  0.1083], grad_fn=<AddBackward0>)
# states
# tensor([-0.6852,  1.3613,  1.3621,  0.9861], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.6852,  1.3613,  1.3621,  0.9861], grad_fn=<AddBackward0>)
# states
# tensor([-1.1714,  2.6479,  2.5782,  2.0063], grad_fn=<AddBackward0>)
# q_pred= tensor([-1.1714,  2.6479,  2.5782,  2.0063], grad_fn=<AddBackward0>)
# states
# tensor([-0.1238,  0.3498,  0.2670,  0.1105], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1238,  0.3498,  0.2670,  0.1105], grad_fn=<AddBackward0>)
# states
# tensor([-0.3511,  0.4350,  0.4303,  0.1716], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3511,  0.4350,  0.4303,  0.1716], grad_fn=<AddBackward0>)
# states
# tensor([-0.4794,  0.6991,  0.7169,  0.4647], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4794,  0.6991,  0.7169,  0.4647], grad_fn=<AddBackward0>)
# states
# tensor([-0.3465,  0.4277,  0.4298,  0.1733], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3465,  0.4277,  0.4298,  0.1733], grad_fn=<AddBackward0>)
# states
# tensor([-0.1177,  0.3438,  0.2670,  0.1133], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1177,  0.3438,  0.2670,  0.1133], grad_fn=<AddBackward0>)
# states
# tensor([-0.1165,  0.3426,  0.2668,  0.1142], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1165,  0.3426,  0.2668,  0.1142], grad_fn=<AddBackward0>)
# states
# tensor([-0.1152,  0.3414,  0.2667,  0.1149], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1152,  0.3414,  0.2667,  0.1149], grad_fn=<AddBackward0>)
# states
# tensor([-0.1140,  0.3403,  0.2666,  0.1156], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1140,  0.3403,  0.2666,  0.1156], grad_fn=<AddBackward0>)
# states
# tensor([-0.1129,  0.3392,  0.2665,  0.1162], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1129,  0.3392,  0.2665,  0.1162], grad_fn=<AddBackward0>)
# states
# tensor([-0.1118,  0.3381,  0.2664,  0.1168], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1118,  0.3381,  0.2664,  0.1168], grad_fn=<AddBackward0>)
# states
# tensor([-0.3349,  0.4115,  0.4265,  0.1777], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3349,  0.4115,  0.4265,  0.1777], grad_fn=<AddBackward0>)
# states
# tensor([-0.3338,  0.4099,  0.4262,  0.1781], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3338,  0.4099,  0.4262,  0.1781], grad_fn=<AddBackward0>)
# states
# tensor([-0.1090,  0.3356,  0.2661,  0.1182], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1090,  0.3356,  0.2661,  0.1182], grad_fn=<AddBackward0>)
# states
# tensor([-0.3318,  0.4077,  0.4247,  0.1788], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3318,  0.4077,  0.4247,  0.1788], grad_fn=<AddBackward0>)
# states
# tensor([-0.4523,  0.6565,  0.7057,  0.4728], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4523,  0.6565,  0.7057,  0.4728], grad_fn=<AddBackward0>)
# states
# tensor([-0.5359,  0.9293,  1.0219,  0.7387], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.5359,  0.9293,  1.0219,  0.7387], grad_fn=<AddBackward0>)
# states
# tensor([-0.4501,  0.6535,  0.7033,  0.4743], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4501,  0.6535,  0.7033,  0.4743], grad_fn=<AddBackward0>)
# states
# tensor([-0.3287,  0.4046,  0.4217,  0.1806], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3287,  0.4046,  0.4217,  0.1806], grad_fn=<AddBackward0>)
# states
# tensor([-0.1051,  0.3338,  0.2638,  0.1207], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1051,  0.3338,  0.2638,  0.1207], grad_fn=<AddBackward0>)
# states
# tensor([-0.1046,  0.3337,  0.2632,  0.1213], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1046,  0.3337,  0.2632,  0.1213], grad_fn=<AddBackward0>)
# states
# tensor([-0.3266,  0.4036,  0.4184,  0.1821], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3266,  0.4036,  0.4184,  0.1821], grad_fn=<AddBackward0>)
# states
# tensor([-0.4453,  0.6489,  0.6950,  0.4774], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4453,  0.6489,  0.6950,  0.4774], grad_fn=<AddBackward0>)
# states
# tensor([-0.3256,  0.4030,  0.4163,  0.1836], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3256,  0.4030,  0.4163,  0.1836], grad_fn=<AddBackward0>)
# states
# tensor([-0.3251,  0.4027,  0.4154,  0.1843], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3251,  0.4027,  0.4154,  0.1843], grad_fn=<AddBackward0>)
# states
# tensor([-0.1027,  0.3333,  0.2605,  0.1258], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1027,  0.3333,  0.2605,  0.1258], grad_fn=<AddBackward0>)
# states
# tensor([-0.5964,  1.2105,  1.3081,  1.0155], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.5964,  1.2105,  1.3081,  1.0155], grad_fn=<AddBackward0>)
# states
# tensor([-0.1021,  0.3339,  0.2594,  0.1272], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1021,  0.3339,  0.2594,  0.1272], grad_fn=<AddBackward0>)
# states
# tensor([-0.1019,  0.3341,  0.2589,  0.1280], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1019,  0.3341,  0.2589,  0.1280], grad_fn=<AddBackward0>)
# states
# tensor([-0.3235,  0.4023,  0.4109,  0.1871], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3235,  0.4023,  0.4109,  0.1871], grad_fn=<AddBackward0>)
# states
# tensor([-0.3232,  0.4023,  0.4102,  0.1877], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3232,  0.4023,  0.4102,  0.1877], grad_fn=<AddBackward0>)
# states
# tensor([-0.1013,  0.3345,  0.2578,  0.1303], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1013,  0.3345,  0.2578,  0.1303], grad_fn=<AddBackward0>)
# states
# tensor([-0.3228,  0.4022,  0.4088,  0.1889], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3228,  0.4022,  0.4088,  0.1889], grad_fn=<AddBackward0>)
# states
# tensor([-0.4403,  0.6450,  0.6808,  0.4839], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4403,  0.6450,  0.6808,  0.4839], grad_fn=<AddBackward0>)
# states
# tensor([-0.5211,  0.9131,  0.9881,  0.7516], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.5211,  0.9131,  0.9881,  0.7516], grad_fn=<AddBackward0>)
# states
# tensor([-0.1008,  0.3352,  0.2561,  0.1340], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1008,  0.3352,  0.2561,  0.1340], grad_fn=<AddBackward0>)
# states
# tensor([-0.3222,  0.4027,  0.4050,  0.1917], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3222,  0.4027,  0.4050,  0.1917], grad_fn=<AddBackward0>)
# states
# tensor([-0.1006,  0.3357,  0.2552,  0.1355], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1006,  0.3357,  0.2552,  0.1355], grad_fn=<AddBackward0>)
# states
# tensor([-0.1006,  0.3359,  0.2548,  0.1364], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1006,  0.3359,  0.2548,  0.1364], grad_fn=<AddBackward0>)
# states
# tensor([-0.1005,  0.3360,  0.2545,  0.1372], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.1005,  0.3360,  0.2545,  0.1372], grad_fn=<AddBackward0>)
# states
# tensor([-0.3218,  0.4033,  0.4014,  0.1941], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3218,  0.4033,  0.4014,  0.1941], grad_fn=<AddBackward0>)
# states
# tensor([-0.4391,  0.6462,  0.6687,  0.4894], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4391,  0.6462,  0.6687,  0.4894], grad_fn=<AddBackward0>)
# states
# tensor([-0.4386,  0.6462,  0.6672,  0.4899], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4386,  0.6462,  0.6672,  0.4899], grad_fn=<AddBackward0>)
# states
# tensor([-0.5186,  0.9150,  0.9683,  0.7579], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.5186,  0.9150,  0.9683,  0.7579], grad_fn=<AddBackward0>)
# states
# tensor([-0.4378,  0.6466,  0.6644,  0.4906], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4378,  0.6466,  0.6644,  0.4906], grad_fn=<AddBackward0>)
# states
# tensor([-0.5177,  0.9153,  0.9649,  0.7585], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.5177,  0.9153,  0.9649,  0.7585], grad_fn=<AddBackward0>)
# states
# tensor([-0.5174,  0.9155,  0.9634,  0.7587], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.5174,  0.9155,  0.9634,  0.7587], grad_fn=<AddBackward0>)
# states
# tensor([-0.5170,  0.9156,  0.9620,  0.7591], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.5170,  0.9156,  0.9620,  0.7591], grad_fn=<AddBackward0>)
# states
# tensor([-0.0991,  0.3364,  0.2515,  0.1434], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0991,  0.3364,  0.2515,  0.1434], grad_fn=<AddBackward0>)
# states
# tensor([-0.5861,  1.2088,  1.2516,  1.0307], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.5861,  1.2088,  1.2516,  1.0307], grad_fn=<AddBackward0>)
# states
# tensor([-0.0989,  0.3365,  0.2518,  0.1444], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0989,  0.3365,  0.2518,  0.1444], grad_fn=<AddBackward0>)
# states
# tensor([-0.5855,  1.2090,  1.2438,  1.0334], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.5855,  1.2090,  1.2438,  1.0334], grad_fn=<AddBackward0>)
# states
# tensor([-0.0988,  0.3366,  0.2528,  0.1456], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0988,  0.3366,  0.2528,  0.1456], grad_fn=<AddBackward0>)
# states
# tensor([-0.5851,  1.2091,  1.2346,  1.0375], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.5851,  1.2091,  1.2346,  1.0375], grad_fn=<AddBackward0>)
# states
# tensor([-0.0986,  0.3370,  0.2543,  0.1464], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0986,  0.3370,  0.2543,  0.1464], grad_fn=<AddBackward0>)
# states
# tensor([-0.0984,  0.3371,  0.2549,  0.1466], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0984,  0.3371,  0.2549,  0.1466], grad_fn=<AddBackward0>)
# states
# tensor([-0.5845,  1.2095,  1.2217,  1.0372], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.5845,  1.2095,  1.2217,  1.0372], grad_fn=<AddBackward0>)
# states
# tensor([-0.0979,  0.3386,  0.2555,  0.1469], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0979,  0.3386,  0.2555,  0.1469], grad_fn=<AddBackward0>)
# states
# tensor([-0.5841,  1.2101,  1.2109,  1.0370], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.5841,  1.2101,  1.2109,  1.0370], grad_fn=<AddBackward0>)
# states
# tensor([-0.5840,  1.2103,  1.2059,  1.0369], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.5840,  1.2103,  1.2059,  1.0369], grad_fn=<AddBackward0>)
# states
# tensor([-0.9825,  2.3586,  2.2688,  2.0901], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.9825,  2.3586,  2.2688,  2.0901], grad_fn=<AddBackward0>)
# states
# tensor([-0.9717,  2.3467,  2.2608,  2.0900], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.9717,  2.3467,  2.2608,  2.0900], grad_fn=<AddBackward0>)
# states
# tensor([-0.9620,  2.3361,  2.2535,  2.0900], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.9620,  2.3361,  2.2535,  2.0900], grad_fn=<AddBackward0>)
# states
# tensor([-0.9533,  2.3264,  2.2470,  2.0900], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.9533,  2.3264,  2.2470,  2.0900], grad_fn=<AddBackward0>)
# states
# tensor([-0.9454,  2.3176,  2.2411,  2.0900], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.9454,  2.3176,  2.2411,  2.0900], grad_fn=<AddBackward0>)
# states
# tensor([-0.0941,  0.3401,  0.2592,  0.1477], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0941,  0.3401,  0.2592,  0.1477], grad_fn=<AddBackward0>)
# states
# tensor([-0.3103,  0.3979,  0.3802,  0.2010], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3103,  0.3979,  0.3802,  0.2010], grad_fn=<AddBackward0>)
# states
# tensor([-0.4197,  0.6294,  0.6258,  0.4967], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4197,  0.6294,  0.6258,  0.4967], grad_fn=<AddBackward0>)
# states
# tensor([-0.4906,  0.8847,  0.9085,  0.7664], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4906,  0.8847,  0.9085,  0.7664], grad_fn=<AddBackward0>)
# states
# tensor([-0.4888,  0.8813,  0.9081,  0.7672], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4888,  0.8813,  0.9081,  0.7672], grad_fn=<AddBackward0>)
# states
# tensor([-0.4871,  0.8783,  0.9077,  0.7680], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4871,  0.8783,  0.9077,  0.7680], grad_fn=<AddBackward0>)
# states
# tensor([-0.4144,  0.6206,  0.6243,  0.4993], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4144,  0.6206,  0.6243,  0.4993], grad_fn=<AddBackward0>)
# states
# tensor([-0.4130,  0.6190,  0.6237,  0.4998], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4130,  0.6190,  0.6237,  0.4998], grad_fn=<AddBackward0>)
# states
# tensor([-0.4814,  0.8710,  0.9050,  0.7699], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4814,  0.8710,  0.9050,  0.7699], grad_fn=<AddBackward0>)
# states
# tensor([-0.4107,  0.6162,  0.6224,  0.5005], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4107,  0.6162,  0.6224,  0.5005], grad_fn=<AddBackward0>)
# states
# tensor([-0.4784,  0.8675,  0.9034,  0.7703], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4784,  0.8675,  0.9034,  0.7703], grad_fn=<AddBackward0>)
# states
# tensor([-0.4772,  0.8660,  0.9025,  0.7706], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4772,  0.8660,  0.9025,  0.7706], grad_fn=<AddBackward0>)
# states
# tensor([-0.4760,  0.8647,  0.9017,  0.7711], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4760,  0.8647,  0.9017,  0.7711], grad_fn=<AddBackward0>)
# states
# tensor([-0.4068,  0.6126,  0.6195,  0.5016], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4068,  0.6126,  0.6195,  0.5016], grad_fn=<AddBackward0>)
# states
# tensor([-0.4057,  0.6118,  0.6186,  0.5019], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4057,  0.6118,  0.6186,  0.5019], grad_fn=<AddBackward0>)
# states
# tensor([-0.4716,  0.8616,  0.8979,  0.7721], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4716,  0.8616,  0.8979,  0.7721], grad_fn=<AddBackward0>)
# states
# tensor([-0.4039,  0.6108,  0.6169,  0.5022], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4039,  0.6108,  0.6169,  0.5022], grad_fn=<AddBackward0>)
# states
# tensor([-0.2992,  0.3863,  0.3746,  0.2057], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2992,  0.3863,  0.3746,  0.2057], grad_fn=<AddBackward0>)
# states
# tensor([-0.0877,  0.3375,  0.2598,  0.1519], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0877,  0.3375,  0.2598,  0.1519], grad_fn=<AddBackward0>)
# states
# tensor([-0.0875,  0.3377,  0.2595,  0.1519], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0875,  0.3377,  0.2595,  0.1519], grad_fn=<AddBackward0>)
# states
# tensor([-0.5212,  1.1327,  1.1620,  1.0449], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.5212,  1.1327,  1.1620,  1.0449], grad_fn=<AddBackward0>)
# states
# tensor([-0.0860,  0.3381,  0.2585,  0.1522], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0860,  0.3381,  0.2585,  0.1522], grad_fn=<AddBackward0>)
# states
# tensor([-0.2965,  0.3865,  0.3695,  0.2064], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2965,  0.3865,  0.3695,  0.2064], grad_fn=<AddBackward0>)
# states
# tensor([-0.2959,  0.3863,  0.3685,  0.2068], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2959,  0.3863,  0.3685,  0.2068], grad_fn=<AddBackward0>)
# states
# tensor([-0.2953,  0.3862,  0.3676,  0.2071], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2953,  0.3862,  0.3676,  0.2071], grad_fn=<AddBackward0>)
# states
# tensor([-0.3975,  0.6084,  0.6032,  0.5046], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3975,  0.6084,  0.6032,  0.5046], grad_fn=<AddBackward0>)
# states
# tensor([-0.2943,  0.3857,  0.3661,  0.2082], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2943,  0.3857,  0.3661,  0.2082], grad_fn=<AddBackward0>)
# states
# tensor([-0.0823,  0.3376,  0.2563,  0.1551], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0823,  0.3376,  0.2563,  0.1551], grad_fn=<AddBackward0>)
# states
# tensor([-0.2935,  0.3851,  0.3649,  0.2094], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2935,  0.3851,  0.3649,  0.2094], grad_fn=<AddBackward0>)
# states
# tensor([-0.0813,  0.3369,  0.2558,  0.1566], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0813,  0.3369,  0.2558,  0.1566], grad_fn=<AddBackward0>)
# states
# tensor([-0.2925,  0.3843,  0.3639,  0.2104], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2925,  0.3843,  0.3639,  0.2104], grad_fn=<AddBackward0>)
# states
# tensor([-0.3945,  0.6058,  0.5976,  0.5080], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3945,  0.6058,  0.5976,  0.5080], grad_fn=<AddBackward0>)
# states
# tensor([-0.6609,  1.6533,  1.6384,  1.5937], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.6609,  1.6533,  1.6384,  1.5937], grad_fn=<AddBackward0>)
# states
# tensor([-0.0796,  0.3348,  0.2560,  0.1588], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0796,  0.3348,  0.2560,  0.1588], grad_fn=<AddBackward0>)
# states
# tensor([-0.0793,  0.3341,  0.2562,  0.1594], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0793,  0.3341,  0.2562,  0.1594], grad_fn=<AddBackward0>)
# states
# tensor([-0.2909,  0.3808,  0.3640,  0.2126], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2909,  0.3808,  0.3640,  0.2126], grad_fn=<AddBackward0>)
# states
# tensor([-0.3929,  0.6002,  0.5979,  0.5101], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3929,  0.6002,  0.5979,  0.5101], grad_fn=<AddBackward0>)
# states
# tensor([-0.6580,  1.6384,  1.6396,  1.5971], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.6580,  1.6384,  1.6396,  1.5971], grad_fn=<AddBackward0>)
# states
# tensor([-0.0779,  0.3316,  0.2572,  0.1614], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0779,  0.3316,  0.2572,  0.1614], grad_fn=<AddBackward0>)
# states
# tensor([-0.2884,  0.3772,  0.3637,  0.2140], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2884,  0.3772,  0.3637,  0.2140], grad_fn=<AddBackward0>)
# states
# tensor([-0.3881,  0.5945,  0.5955,  0.5114], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3881,  0.5945,  0.5955,  0.5114], grad_fn=<AddBackward0>)
# states
# tensor([-0.4480,  0.8365,  0.8645,  0.7834], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4480,  0.8365,  0.8645,  0.7834], grad_fn=<AddBackward0>)
# states
# tensor([-0.4465,  0.8352,  0.8631,  0.7837], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4465,  0.8352,  0.8631,  0.7837], grad_fn=<AddBackward0>)
# states
# tensor([-0.4451,  0.8341,  0.8619,  0.7841], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4451,  0.8341,  0.8619,  0.7841], grad_fn=<AddBackward0>)
# states
# tensor([-0.4430,  0.8330,  0.8598,  0.7844], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4430,  0.8330,  0.8598,  0.7844], grad_fn=<AddBackward0>)
# states
# tensor([-0.3819,  0.5900,  0.5902,  0.5128], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3819,  0.5900,  0.5902,  0.5128], grad_fn=<AddBackward0>)
# states
# tensor([-0.3807,  0.5893,  0.5891,  0.5131], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3807,  0.5893,  0.5891,  0.5131], grad_fn=<AddBackward0>)
# states
# tensor([-0.2822,  0.3725,  0.3595,  0.2162], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2822,  0.3725,  0.3595,  0.2162], grad_fn=<AddBackward0>)
# states
# tensor([-0.0734,  0.3279,  0.2560,  0.1660], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0734,  0.3279,  0.2560,  0.1660], grad_fn=<AddBackward0>)
# states
# tensor([-0.0729,  0.3277,  0.2557,  0.1662], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0729,  0.3277,  0.2557,  0.1662], grad_fn=<AddBackward0>)
# states
# tensor([-0.0722,  0.3273,  0.2554,  0.1665], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0722,  0.3273,  0.2554,  0.1665], grad_fn=<AddBackward0>)
# states
# tensor([-0.0716,  0.3268,  0.2551,  0.1669], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0716,  0.3268,  0.2551,  0.1669], grad_fn=<AddBackward0>)
# states
# tensor([-0.4779,  1.0917,  1.1019,  1.0615], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4779,  1.0917,  1.1019,  1.0615], grad_fn=<AddBackward0>)
# states
# tensor([-0.7800,  2.1265,  2.0720,  2.1217], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.7800,  2.1265,  2.0720,  2.1217], grad_fn=<AddBackward0>)
# states
# tensor([-0.7680,  2.1172,  2.0664,  2.1133], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.7680,  2.1172,  2.0664,  2.1133], grad_fn=<AddBackward0>)
# states
# tensor([-0.4648,  1.0832,  1.0918,  1.0489], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4648,  1.0832,  1.0918,  1.0489], grad_fn=<AddBackward0>)
# states
# tensor([-0.4598,  1.0794,  1.0882,  1.0456], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4598,  1.0794,  1.0882,  1.0456], grad_fn=<AddBackward0>)
# states
# tensor([-0.0641,  0.3235,  0.2527,  0.1665], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0641,  0.3235,  0.2527,  0.1665], grad_fn=<AddBackward0>)
# states
# tensor([-0.2689,  0.3653,  0.3494,  0.2119], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2689,  0.3653,  0.3494,  0.2119], grad_fn=<AddBackward0>)
# states
# tensor([-0.0622,  0.3224,  0.2521,  0.1665], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0622,  0.3224,  0.2521,  0.1665], grad_fn=<AddBackward0>)
# states
# tensor([-0.0611,  0.3217,  0.2519,  0.1665], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0611,  0.3217,  0.2519,  0.1665], grad_fn=<AddBackward0>)
# states
# tensor([-0.2652,  0.3625,  0.3474,  0.2110], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2652,  0.3625,  0.3474,  0.2110], grad_fn=<AddBackward0>)
# states
# tensor([-0.2641,  0.3616,  0.3469,  0.2109], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2641,  0.3616,  0.3469,  0.2109], grad_fn=<AddBackward0>)
# states
# tensor([-0.3515,  0.5691,  0.5648,  0.5010], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3515,  0.5691,  0.5648,  0.5010], grad_fn=<AddBackward0>)
# states
# tensor([-0.3974,  0.8003,  0.8199,  0.7652], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3974,  0.8003,  0.8199,  0.7652], grad_fn=<AddBackward0>)
# states
# tensor([-0.3959,  0.7988,  0.8189,  0.7647], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3959,  0.7988,  0.8189,  0.7647], grad_fn=<AddBackward0>)
# states
# tensor([-0.3945,  0.7975,  0.8179,  0.7642], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3945,  0.7975,  0.8179,  0.7642], grad_fn=<AddBackward0>)
# states
# tensor([-0.3472,  0.5651,  0.5622,  0.4998], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3472,  0.5651,  0.5622,  0.4998], grad_fn=<AddBackward0>)
# states
# tensor([-0.5384,  1.5471,  1.5322,  1.5495], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.5384,  1.5471,  1.5322,  1.5495], grad_fn=<AddBackward0>)
# states
# tensor([-0.3448,  0.5639,  0.5612,  0.4957], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3448,  0.5639,  0.5612,  0.4957], grad_fn=<AddBackward0>)
# states
# tensor([-0.5290,  1.5396,  1.5295,  1.5387], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.5290,  1.5396,  1.5295,  1.5387], grad_fn=<AddBackward0>)
# states
# tensor([-0.3408,  0.5604,  0.5603,  0.4903], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3408,  0.5604,  0.5603,  0.4903], grad_fn=<AddBackward0>)
# states
# tensor([-0.2548,  0.3544,  0.3440,  0.2036], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2548,  0.3544,  0.3440,  0.2036], grad_fn=<AddBackward0>)
# states
# tensor([-0.0518,  0.3147,  0.2506,  0.1657], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0518,  0.3147,  0.2506,  0.1657], grad_fn=<AddBackward0>)
# states
# tensor([-0.0509,  0.3139,  0.2506,  0.1652], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0509,  0.3139,  0.2506,  0.1652], grad_fn=<AddBackward0>)
# states
# tensor([-0.0502,  0.3132,  0.2507,  0.1647], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0502,  0.3132,  0.2507,  0.1647], grad_fn=<AddBackward0>)
# states
# tensor([-0.4024,  1.0310,  1.0582,  0.9859], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.4024,  1.0310,  1.0582,  0.9859], grad_fn=<AddBackward0>)
# states
# tensor([-0.6303,  1.9957,  1.9884,  1.9712], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.6303,  1.9957,  1.9884,  1.9712], grad_fn=<AddBackward0>)
# states
# tensor([-0.6228,  1.9852,  1.9853,  1.9645], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.6228,  1.9852,  1.9853,  1.9645], grad_fn=<AddBackward0>)
# states
# tensor([-0.6909,  2.2138,  2.2141,  2.2025], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.6909,  2.2138,  2.2141,  2.2025], grad_fn=<AddBackward0>)
# states
# tensor([-0.0437,  0.3087,  0.2501,  0.1624], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0437,  0.3087,  0.2501,  0.1624], grad_fn=<AddBackward0>)
# states
# tensor([-0.0425,  0.3078,  0.2502,  0.1616], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0425,  0.3078,  0.2502,  0.1616], grad_fn=<AddBackward0>)
# states
# tensor([-0.0414,  0.3069,  0.2503,  0.1610], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0414,  0.3069,  0.2503,  0.1610], grad_fn=<AddBackward0>)
# states
# tensor([-0.0405,  0.3060,  0.2504,  0.1605], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0405,  0.3060,  0.2504,  0.1605], grad_fn=<AddBackward0>)
# states
# tensor([-0.3759,  0.9955,  1.0532,  0.9450], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3759,  0.9955,  1.0532,  0.9450], grad_fn=<AddBackward0>)
# states
# tensor([-0.5867,  1.9322,  1.9782,  1.8882], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.5867,  1.9322,  1.9782,  1.8882], grad_fn=<AddBackward0>)
# states
# tensor([-0.0359,  0.3039,  0.2488,  0.1595], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0359,  0.3039,  0.2488,  0.1595], grad_fn=<AddBackward0>)
# states
# tensor([-0.3586,  0.9876,  1.0266,  0.9324], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3586,  0.9876,  1.0266,  0.9324], grad_fn=<AddBackward0>)
# states
# tensor([-0.0317,  0.3032,  0.2460,  0.1590], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0317,  0.3032,  0.2460,  0.1590], grad_fn=<AddBackward0>)
# states
# tensor([-0.3460,  0.9837,  1.0028,  0.9257], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3460,  0.9837,  1.0028,  0.9257], grad_fn=<AddBackward0>)
# states
# tensor([-0.3393,  0.9820,  0.9906,  0.9229], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3393,  0.9820,  0.9906,  0.9229], grad_fn=<AddBackward0>)
# states
# tensor([-0.3320,  0.9805,  0.9782,  0.9203], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.3320,  0.9805,  0.9782,  0.9203], grad_fn=<AddBackward0>)
# states
# tensor([-0.0227,  0.3033,  0.2398,  0.1582], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0227,  0.3033,  0.2398,  0.1582], grad_fn=<AddBackward0>)
# states
# tensor([-0.0208,  0.3036,  0.2384,  0.1580], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0208,  0.3036,  0.2384,  0.1580], grad_fn=<AddBackward0>)
# states
# tensor([-0.2141,  0.3342,  0.3097,  0.1776], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2141,  0.3342,  0.3097,  0.1776], grad_fn=<AddBackward0>)
# states
# tensor([-0.0174,  0.3038,  0.2359,  0.1578], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0174,  0.3038,  0.2359,  0.1578], grad_fn=<AddBackward0>)
# states
# tensor([-0.2103,  0.3338,  0.3046,  0.1767], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2103,  0.3338,  0.3046,  0.1767], grad_fn=<AddBackward0>)
# states
# tensor([-0.2728,  0.5239,  0.4868,  0.4378], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2728,  0.5239,  0.4868,  0.4378], grad_fn=<AddBackward0>)
# states
# tensor([-0.2707,  0.5234,  0.4835,  0.4371], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.2707,  0.5234,  0.4835,  0.4371], grad_fn=<AddBackward0>)
# states
# ...
# states
# tensor([0.0367, 0.2673, 0.2660, 0.2195], grad_fn=<AddBackward0>)
# q_pred= tensor([0.0367, 0.2673, 0.2660, 0.2195], grad_fn=<AddBackward0>)
# states
# tensor([0.4493, 0.6899, 0.6826, 0.6777], grad_fn=<AddBackward0>)
# q_pred= tensor([0.4493, 0.6899, 0.6826, 0.6777], grad_fn=<AddBackward0>)
# states
# tensor([0.1224, 0.2415, 0.2171, 0.1586], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1224, 0.2415, 0.2171, 0.1586], grad_fn=<AddBackward0>)
# states
# tensor([0.1226, 0.2414, 0.2172, 0.1586], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1226, 0.2414, 0.2172, 0.1586], grad_fn=<AddBackward0>)
# states
# tensor([0.2558, 0.4711, 0.4895, 0.4514], grad_fn=<AddBackward0>)
# q_pred= tensor([0.2558, 0.4711, 0.4895, 0.4514], grad_fn=<AddBackward0>)
# states
# tensor([0.6209, 0.8926, 0.8759, 0.8897], grad_fn=<AddBackward0>)
# q_pred= tensor([0.6209, 0.8926, 0.8759, 0.8897], grad_fn=<AddBackward0>)
# states
# tensor([0.1233, 0.2408, 0.2181, 0.1582], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1233, 0.2408, 0.2181, 0.1582], grad_fn=<AddBackward0>)
# states
# tensor([0.2586, 0.4644, 0.4895, 0.4454], grad_fn=<AddBackward0>)
# q_pred= tensor([0.2586, 0.4644, 0.4895, 0.4454], grad_fn=<AddBackward0>)
# states
# tensor([0.6268, 0.8780, 0.8775, 0.8737], grad_fn=<AddBackward0>)
# q_pred= tensor([0.6268, 0.8780, 0.8775, 0.8737], grad_fn=<AddBackward0>)
# states
# tensor([0.2614, 0.4584, 0.4904, 0.4388], grad_fn=<AddBackward0>)
# q_pred= tensor([0.2614, 0.4584, 0.4904, 0.4388], grad_fn=<AddBackward0>)
# states
# tensor([0.2626, 0.4559, 0.4910, 0.4351], grad_fn=<AddBackward0>)
# q_pred= tensor([0.2626, 0.4559, 0.4910, 0.4351], grad_fn=<AddBackward0>)
# states
# tensor([0.1247, 0.2396, 0.2205, 0.1563], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1247, 0.2396, 0.2205, 0.1563], grad_fn=<AddBackward0>)
# states
# tensor([-0.0018,  0.1831,  0.1886,  0.0654], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0018,  0.1831,  0.1886,  0.0654], grad_fn=<AddBackward0>)
# states
# tensor([-0.0014,  0.1826,  0.1887,  0.0646], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0014,  0.1826,  0.1887,  0.0646], grad_fn=<AddBackward0>)
# states
# tensor([-0.0011,  0.1821,  0.1888,  0.0639], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0011,  0.1821,  0.1888,  0.0639], grad_fn=<AddBackward0>)
# states
# tensor([0.1256, 0.2394, 0.2214, 0.1551], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1256, 0.2394, 0.2214, 0.1551], grad_fn=<AddBackward0>)
# states
# tensor([-0.0004,  0.1817,  0.1884,  0.0627], grad_fn=<AddBackward0>)
# q_pred= tensor([-0.0004,  0.1817,  0.1884,  0.0627], grad_fn=<AddBackward0>)
# states
# tensor([0.1260, 0.2394, 0.2215, 0.1549], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1260, 0.2394, 0.2215, 0.1549], grad_fn=<AddBackward0>)
# states
# tensor([0.1261, 0.2393, 0.2215, 0.1551], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1261, 0.2393, 0.2215, 0.1551], grad_fn=<AddBackward0>)
# states
# tensor([0.1263, 0.2391, 0.2216, 0.1554], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1263, 0.2391, 0.2216, 0.1554], grad_fn=<AddBackward0>)
# states
# tensor([0.1264, 0.2390, 0.2216, 0.1556], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1264, 0.2390, 0.2216, 0.1556], grad_fn=<AddBackward0>)
# states
# tensor([0.0007, 0.1804, 0.1878, 0.0616], grad_fn=<AddBackward0>)
# q_pred= tensor([0.0007, 0.1804, 0.1878, 0.0616], grad_fn=<AddBackward0>)
# states
# tensor([0.1266, 0.2389, 0.2215, 0.1561], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1266, 0.2389, 0.2215, 0.1561], grad_fn=<AddBackward0>)
# states
# tensor([0.0010, 0.1803, 0.1872, 0.0614], grad_fn=<AddBackward0>)
# q_pred= tensor([0.0010, 0.1803, 0.1872, 0.0614], grad_fn=<AddBackward0>)
# states
# tensor([0.1268, 0.2390, 0.2212, 0.1565], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1268, 0.2390, 0.2212, 0.1565], grad_fn=<AddBackward0>)
# states
# tensor([0.2718, 0.4397, 0.4821, 0.4097], grad_fn=<AddBackward0>)
# q_pred= tensor([0.2718, 0.4397, 0.4821, 0.4097], grad_fn=<AddBackward0>)
# states
# tensor([0.6494, 0.8340, 0.8565, 0.8054], grad_fn=<AddBackward0>)
# q_pred= tensor([0.6494, 0.8340, 0.8565, 0.8054], grad_fn=<AddBackward0>)
# states
# tensor([0.7295, 0.9305, 0.9420, 0.9007], grad_fn=<AddBackward0>)
# q_pred= tensor([0.7295, 0.9305, 0.9420, 0.9007], grad_fn=<AddBackward0>)
# states
# tensor([0.1274, 0.2402, 0.2199, 0.1571], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1274, 0.2402, 0.2199, 0.1571], grad_fn=<AddBackward0>)
# states
# tensor([0.1276, 0.2404, 0.2197, 0.1570], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1276, 0.2404, 0.2197, 0.1570], grad_fn=<AddBackward0>)
# states
# tensor([0.0028, 0.1814, 0.1823, 0.0597], grad_fn=<AddBackward0>)
# q_pred= tensor([0.0028, 0.1814, 0.1823, 0.0597], grad_fn=<AddBackward0>)
# states
# tensor([0.1280, 0.2408, 0.2191, 0.1569], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1280, 0.2408, 0.2191, 0.1569], grad_fn=<AddBackward0>)
# states
# tensor([0.0035, 0.1816, 0.1807, 0.0590], grad_fn=<AddBackward0>)
# q_pred= tensor([0.0035, 0.1816, 0.1807, 0.0590], grad_fn=<AddBackward0>)
# states
# tensor([0.0039, 0.1816, 0.1801, 0.0587], grad_fn=<AddBackward0>)
# q_pred= tensor([0.0039, 0.1816, 0.1801, 0.0587], grad_fn=<AddBackward0>)
# states
# tensor([0.0043, 0.1816, 0.1795, 0.0584], grad_fn=<AddBackward0>)
# q_pred= tensor([0.0043, 0.1816, 0.1795, 0.0584], grad_fn=<AddBackward0>)
# states
# tensor([0.1292, 0.2409, 0.2180, 0.1571], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1292, 0.2409, 0.2180, 0.1571], grad_fn=<AddBackward0>)
# states
# tensor([0.2796, 0.4381, 0.4563, 0.3962], grad_fn=<AddBackward0>)
# q_pred= tensor([0.2796, 0.4381, 0.4563, 0.3962], grad_fn=<AddBackward0>)
# states
# tensor([0.6623, 0.8292, 0.8092, 0.7778], grad_fn=<AddBackward0>)
# q_pred= tensor([0.6623, 0.8292, 0.8092, 0.7778], grad_fn=<AddBackward0>)
# states
# tensor([0.7432, 0.9239, 0.8927, 0.8696], grad_fn=<AddBackward0>)
# q_pred= tensor([0.7432, 0.9239, 0.8927, 0.8696], grad_fn=<AddBackward0>)
# states
# tensor([0.6640, 0.8261, 0.8034, 0.7773], grad_fn=<AddBackward0>)
# q_pred= tensor([0.6640, 0.8261, 0.8034, 0.7773], grad_fn=<AddBackward0>)
# states
# tensor([0.2816, 0.4354, 0.4497, 0.3952], grad_fn=<AddBackward0>)
# q_pred= tensor([0.2816, 0.4354, 0.4497, 0.3952], grad_fn=<AddBackward0>)
# states
# tensor([0.1305, 0.2409, 0.2166, 0.1580], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1305, 0.2409, 0.2166, 0.1580], grad_fn=<AddBackward0>)
# states
# tensor([0.0066, 0.1806, 0.1753, 0.0585], grad_fn=<AddBackward0>)
# q_pred= tensor([0.0066, 0.1806, 0.1753, 0.0585], grad_fn=<AddBackward0>)
# states
# tensor([0.0067, 0.1804, 0.1749, 0.0587], grad_fn=<AddBackward0>)
# q_pred= tensor([0.0067, 0.1804, 0.1749, 0.0587], grad_fn=<AddBackward0>)
# states
# tensor([0.1310, 0.2409, 0.2161, 0.1586], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1310, 0.2409, 0.2161, 0.1586], grad_fn=<AddBackward0>)
# states
# tensor([0.1311, 0.2409, 0.2159, 0.1588], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1311, 0.2409, 0.2159, 0.1588], grad_fn=<AddBackward0>)
# states
# tensor([0.2836, 0.4317, 0.4405, 0.3953], grad_fn=<AddBackward0>)
# q_pred= tensor([0.2836, 0.4317, 0.4405, 0.3953], grad_fn=<AddBackward0>)
# states
# tensor([0.1317, 0.2411, 0.2155, 0.1591], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1317, 0.2411, 0.2155, 0.1591], grad_fn=<AddBackward0>)
# states
# tensor([0.2842, 0.4306, 0.4375, 0.3944], grad_fn=<AddBackward0>)
# q_pred= tensor([0.2842, 0.4306, 0.4375, 0.3944], grad_fn=<AddBackward0>)
# states
# tensor([0.1322, 0.2413, 0.2156, 0.1592], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1322, 0.2413, 0.2156, 0.1592], grad_fn=<AddBackward0>)
# states
# tensor([0.1324, 0.2414, 0.2156, 0.1592], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1324, 0.2414, 0.2156, 0.1592], grad_fn=<AddBackward0>)
# states
# tensor([0.1326, 0.2415, 0.2156, 0.1593], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1326, 0.2415, 0.2156, 0.1593], grad_fn=<AddBackward0>)
# states
# tensor([0.1328, 0.2415, 0.2156, 0.1595], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1328, 0.2415, 0.2156, 0.1595], grad_fn=<AddBackward0>)
# states
# tensor([0.2851, 0.4287, 0.4315, 0.3930], grad_fn=<AddBackward0>)
# q_pred= tensor([0.2851, 0.4287, 0.4315, 0.3930], grad_fn=<AddBackward0>)
# states
# tensor([0.2852, 0.4284, 0.4304, 0.3929], grad_fn=<AddBackward0>)
# q_pred= tensor([0.2852, 0.4284, 0.4304, 0.3929], grad_fn=<AddBackward0>)
# states
# tensor([0.6711, 0.8080, 0.7611, 0.7715], grad_fn=<AddBackward0>)
# q_pred= tensor([0.6711, 0.8080, 0.7611, 0.7715], grad_fn=<AddBackward0>)
# states
# tensor([0.6717, 0.8055, 0.7604, 0.7712], grad_fn=<AddBackward0>)
# q_pred= tensor([0.6717, 0.8055, 0.7604, 0.7712], grad_fn=<AddBackward0>)
# states
# tensor([0.6723, 0.8033, 0.7598, 0.7709], grad_fn=<AddBackward0>)
# q_pred= tensor([0.6723, 0.8033, 0.7598, 0.7709], grad_fn=<AddBackward0>)
# states
# tensor([0.2856, 0.4239, 0.4297, 0.3923], grad_fn=<AddBackward0>)
# q_pred= tensor([0.2856, 0.4239, 0.4297, 0.3923], grad_fn=<AddBackward0>)
# states
# tensor([0.1335, 0.2411, 0.2172, 0.1604], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1335, 0.2411, 0.2172, 0.1604], grad_fn=<AddBackward0>)
# states
# tensor([0.1335, 0.2410, 0.2174, 0.1607], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1335, 0.2410, 0.2174, 0.1607], grad_fn=<AddBackward0>)
# states
# tensor([0.2846, 0.4215, 0.4298, 0.3921], grad_fn=<AddBackward0>)
# q_pred= tensor([0.2846, 0.4215, 0.4298, 0.3921], grad_fn=<AddBackward0>)
# states
# tensor([0.1336, 0.2408, 0.2181, 0.1612], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1336, 0.2408, 0.2181, 0.1612], grad_fn=<AddBackward0>)
# states
# tensor([0.1336, 0.2407, 0.2184, 0.1614], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1336, 0.2407, 0.2184, 0.1614], grad_fn=<AddBackward0>)
# states
# tensor([0.1337, 0.2405, 0.2186, 0.1616], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1337, 0.2405, 0.2186, 0.1616], grad_fn=<AddBackward0>)
# states
# tensor([0.1338, 0.2403, 0.2189, 0.1618], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1338, 0.2403, 0.2189, 0.1618], grad_fn=<AddBackward0>)
# states
# tensor([0.2835, 0.4181, 0.4291, 0.3930], grad_fn=<AddBackward0>)
# q_pred= tensor([0.2835, 0.4181, 0.4291, 0.3930], grad_fn=<AddBackward0>)
# states
# tensor([0.1341, 0.2402, 0.2192, 0.1621], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1341, 0.2402, 0.2192, 0.1621], grad_fn=<AddBackward0>)
# states
# tensor([0.1342, 0.2401, 0.2193, 0.1622], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1342, 0.2401, 0.2193, 0.1622], grad_fn=<AddBackward0>)
# states
# tensor([0.1344, 0.2399, 0.2194, 0.1625], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1344, 0.2399, 0.2194, 0.1625], grad_fn=<AddBackward0>)
# states
# tensor([0.1346, 0.2398, 0.2195, 0.1628], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1346, 0.2398, 0.2195, 0.1628], grad_fn=<AddBackward0>)
# states
# tensor([0.1348, 0.2395, 0.2196, 0.1630], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1348, 0.2395, 0.2196, 0.1630], grad_fn=<AddBackward0>)
# states
# tensor([0.0088, 0.1755, 0.1718, 0.0605], grad_fn=<AddBackward0>)
# q_pred= tensor([0.0088, 0.1755, 0.1718, 0.0605], grad_fn=<AddBackward0>)
# states
# tensor([0.1352, 0.2390, 0.2198, 0.1634], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1352, 0.2390, 0.2198, 0.1634], grad_fn=<AddBackward0>)
# states
# tensor([0.1355, 0.2386, 0.2199, 0.1635], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1355, 0.2386, 0.2199, 0.1635], grad_fn=<AddBackward0>)
# states
# tensor([0.0092, 0.1749, 0.1717, 0.0608], grad_fn=<AddBackward0>)
# q_pred= tensor([0.0092, 0.1749, 0.1717, 0.0608], grad_fn=<AddBackward0>)
# states
# tensor([0.0094, 0.1747, 0.1717, 0.0608], grad_fn=<AddBackward0>)
# q_pred= tensor([0.0094, 0.1747, 0.1717, 0.0608], grad_fn=<AddBackward0>)
# states
# tensor([0.0095, 0.1745, 0.1716, 0.0609], grad_fn=<AddBackward0>)
# q_pred= tensor([0.0095, 0.1745, 0.1716, 0.0609], grad_fn=<AddBackward0>)
# states
# tensor([0.0561, 0.2357, 0.2332, 0.1922], grad_fn=<AddBackward0>)
# q_pred= tensor([0.0561, 0.2357, 0.2332, 0.1922], grad_fn=<AddBackward0>)
# states
# tensor([0.0097, 0.1741, 0.1716, 0.0613], grad_fn=<AddBackward0>)
# q_pred= tensor([0.0097, 0.1741, 0.1716, 0.0613], grad_fn=<AddBackward0>)
# states
# tensor([0.0098, 0.1738, 0.1715, 0.0616], grad_fn=<AddBackward0>)
# q_pred= tensor([0.0098, 0.1738, 0.1715, 0.0616], grad_fn=<AddBackward0>)
# states
# tensor([0.1369, 0.2366, 0.2198, 0.1651], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1369, 0.2366, 0.2198, 0.1651], grad_fn=<AddBackward0>)
# states
# tensor([0.0100, 0.1737, 0.1711, 0.0621], grad_fn=<AddBackward0>)
# q_pred= tensor([0.0100, 0.1737, 0.1711, 0.0621], grad_fn=<AddBackward0>)
# states
# tensor([0.0102, 0.1735, 0.1709, 0.0623], grad_fn=<AddBackward0>)
# q_pred= tensor([0.0102, 0.1735, 0.1709, 0.0623], grad_fn=<AddBackward0>)
# states
# tensor([0.0568, 0.2347, 0.2316, 0.1934], grad_fn=<AddBackward0>)
# q_pred= tensor([0.0568, 0.2347, 0.2316, 0.1934], grad_fn=<AddBackward0>)
# states
# tensor([0.4894, 0.5933, 0.5820, 0.5902], grad_fn=<AddBackward0>)
# q_pred= tensor([0.4894, 0.5933, 0.5820, 0.5902], grad_fn=<AddBackward0>)
# states
# tensor([0.1380, 0.2356, 0.2192, 0.1661], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1380, 0.2356, 0.2192, 0.1661], grad_fn=<AddBackward0>)
# states
# tensor([0.1382, 0.2354, 0.2191, 0.1662], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1382, 0.2354, 0.2191, 0.1662], grad_fn=<AddBackward0>)
# states
# tensor([0.0114, 0.1722, 0.1701, 0.0626], grad_fn=<AddBackward0>)
# q_pred= tensor([0.0114, 0.1722, 0.1701, 0.0626], grad_fn=<AddBackward0>)
# states
# tensor([0.1387, 0.2352, 0.2189, 0.1664], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1387, 0.2352, 0.2189, 0.1664], grad_fn=<AddBackward0>)
# states
# tensor([0.1388, 0.2352, 0.2187, 0.1665], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1388, 0.2352, 0.2187, 0.1665], grad_fn=<AddBackward0>)
# states
# tensor([0.0120, 0.1720, 0.1692, 0.0626], grad_fn=<AddBackward0>)
# q_pred= tensor([0.0120, 0.1720, 0.1692, 0.0626], grad_fn=<AddBackward0>)
# states
# tensor([0.0121, 0.1719, 0.1689, 0.0627], grad_fn=<AddBackward0>)
# q_pred= tensor([0.0121, 0.1719, 0.1689, 0.0627], grad_fn=<AddBackward0>)
# states
# tensor([0.1394, 0.2350, 0.2182, 0.1668], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1394, 0.2350, 0.2182, 0.1668], grad_fn=<AddBackward0>)
# states
# tensor([0.2878, 0.4050, 0.4169, 0.3943], grad_fn=<AddBackward0>)
# q_pred= tensor([0.2878, 0.4050, 0.4169, 0.3943], grad_fn=<AddBackward0>)
# states
# tensor([0.1403, 0.2348, 0.2178, 0.1671], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1403, 0.2348, 0.2178, 0.1671], grad_fn=<AddBackward0>)
# states
# tensor([0.2884, 0.4033, 0.4149, 0.3942], grad_fn=<AddBackward0>)
# q_pred= tensor([0.2884, 0.4033, 0.4149, 0.3942], grad_fn=<AddBackward0>)
# states
# tensor([0.1410, 0.2346, 0.2177, 0.1673], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1410, 0.2346, 0.2177, 0.1673], grad_fn=<AddBackward0>)
# states
# tensor([0.1414, 0.2345, 0.2177, 0.1674], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1414, 0.2345, 0.2177, 0.1674], grad_fn=<AddBackward0>)
# states
# tensor([0.1417, 0.2344, 0.2177, 0.1674], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1417, 0.2344, 0.2177, 0.1674], grad_fn=<AddBackward0>)
# states
# tensor([0.1420, 0.2343, 0.2177, 0.1675], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1420, 0.2343, 0.2177, 0.1675], grad_fn=<AddBackward0>)
# states
# tensor([0.1423, 0.2342, 0.2177, 0.1676], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1423, 0.2342, 0.2177, 0.1676], grad_fn=<AddBackward0>)
# states
# tensor([0.1425, 0.2341, 0.2177, 0.1676], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1425, 0.2341, 0.2177, 0.1676], grad_fn=<AddBackward0>)
# states
# tensor([0.1428, 0.2340, 0.2177, 0.1677], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1428, 0.2340, 0.2177, 0.1677], grad_fn=<AddBackward0>)
# states
# tensor([0.2900, 0.3990, 0.4089, 0.3937], grad_fn=<AddBackward0>)
# q_pred= tensor([0.2900, 0.3990, 0.4089, 0.3937], grad_fn=<AddBackward0>)
# states
# tensor([0.1433, 0.2339, 0.2180, 0.1677], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1433, 0.2339, 0.2180, 0.1677], grad_fn=<AddBackward0>)
# states
# tensor([0.1435, 0.2339, 0.2181, 0.1676], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1435, 0.2339, 0.2181, 0.1676], grad_fn=<AddBackward0>)
# states
# tensor([0.1438, 0.2338, 0.2182, 0.1676], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1438, 0.2338, 0.2182, 0.1676], grad_fn=<AddBackward0>)
# states
# tensor([0.1440, 0.2337, 0.2183, 0.1677], grad_fn=<AddBackward0>)
# q_pred= tensor([0.1440, 0.2337, 0.2183, 0.1677], grad_fn=<AddBackward0>)
# states
# tensor([0.2906, 0.3977, 0.4060, 0.3915], grad_fn=<AddBackward0>)
# q_pred= tensor([0.2906, 0.3977, 0.4060, 0.3915], grad_fn=<AddBackward0>)
